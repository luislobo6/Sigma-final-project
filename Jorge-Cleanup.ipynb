# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sqlalchemy import create_engine

# %%
data=pd.read_csv("data/data_clean.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 cve_institucion  cve_concepto         200012         200101  \
# 0           0          040002  1.000000e+11  404155.539381  394339.144611
# 1           1          040002  1.100000e+11   25111.100235   24510.989273
# 2           3          040002  1.102000e+11   16499.943715   19677.001561
# 3           4          040002  1.103000e+11     344.422987     272.065783
# 4          14          040002  1.208000e+11    3415.956580     202.787125
#
#           200102         200103         200104         200105         200106  \
# 0  398165.969974  396748.807840  394034.682061  397417.906353  390335.530120
# 1   22223.129407   25016.224513   22234.320323   24171.781379   23781.683570
# 2   17297.767938   20293.765145   17269.417648   19012.391525   19147.689422
# 3     267.612960     278.623623     298.010203     259.137843     178.403780
# 4    2825.408258    2801.145130    3849.574083    7965.414625    6618.111587
#
# ...

# %%
col=data.columns

# %%
data.set_index("Unnamed: 0")
# Out:
#            cve_institucion  cve_concepto        200012        200101  \
# Unnamed: 0
# 0                   040002  1.000000e+11  4.041555e+05  3.943391e+05
# 1                   040002  1.100000e+11  2.511110e+04  2.451099e+04
# 3                   040002  1.102000e+11  1.649994e+04  1.967700e+04
# 4                   040002  1.103000e+11  3.444230e+02  2.720658e+02
# 14                  040002  1.208000e+11  3.415957e+03  2.027871e+02
# ...                    ...           ...           ...           ...
# 29820                   99  6.706000e+11  1.299145e+02  1.649774e+01
# 29821                   99  6.711000e+11  1.333846e+02  1.720747e+01
# 29822                   99  8.000000e+11  1.114730e+04  1.159498e+04
# 29823             99 Total           NaN  8.305512e+04  7.680495e+04
# 29824          Grand Total           NaN  7.002391e+07  6.084185e+07
#
#                   200102        200103        200104        200105  \
# Unnamed: 0
# ...

# %%
col=np.array(col)

# %%
while x>3
# Out:
# array(['Unnamed: 0', 'cve_institucion', 'cve_concepto', '200012',
#        '200101', '200102', '200103', '200104', '200105', '200106',
#        '200107', '200108', '200109', '200110', '200111', '200112',
#        '200201', '200202', '200203', '200204', '200205', '200206',
#        '200207', '200208', '200209', '200210', '200211', '200212',
#        '200301', '200302', '200303', '200304', '200305', '200306',
#        '200307', '200308', '200309', '200310', '200311', '200312',
#        '200401', '200402', '200403', '200404', '200405', '200406',
#        '200407', '200408', '200409', '200410', '200411', '200412',
#        '200501', '200502', '200503', '200504', '200505', '200506',
#        '200507', '200508', '200509', '200510', '200511', '200512',
#        '200601', '200602', '200603', '200604', '200605', '200606',
#        '200607', '200608', '200609', '200610', '200611', '200612',
#        '200701', '200702', '200703', '200704', '200705', '200706',
# ...

# %%
endpoint="banking.cephpaqhv83w.us-east-2.rds.amazonaws.com"
conn= f"postgresql+psycopg2://postgres:2gZq7GdZ7Nw8iuAoRufq@{endpoint}:5432/banking"

# %%
# !pip install psycopg2

# %%
engine = create_engine(conn)

# %%
pd.read_sql("SELECT cve_concepto FROM CONCEPTOS", engine)
# Out:
#     cve_concepto
# 0   5.100000e+11
# 1   6.100000e+11
# 2   6.200000e+11
# 3   6.702000e+11
# 4   6.400000e+11
# 5   6.705000e+11
# 6   6.711000e+11
# 7   1.000000e+11
# 8   1.100000e+11
# 9   1.301000e+11
# 10  1.301050e+11
# 11  1.301060e+11
# 12  1.301210e+11
# 13  1.311000e+11
# 14  1.311010e+11
# 15  1.312000e+11
# 16  1.316000e+11
# 17  2.000000e+11
# 18  2.101000e+11
# 19  2.111000e+11

# %%
test= pd.read_sql("SELECT * FROM data_clean WHERE cve_institucion IN (SELECT bank_id FROM banks)", engine)

# %%
test.head()
# Out:
#   cve_institucion  cve_concepto  2000-12-01 00:00:00  2001-01-01 00:00:00  \
# 0          040002  100000000000        404155.539381        394339.144611
# 1          040002  110000000000         25111.100235         24510.989273
# 2          040002  110200000000         16499.943715         19677.001561
# 3          040002  110300000000           344.422987           272.065783
# 4          040002  120800000000          3415.956580           202.787125
#
#    2001-02-01 00:00:00  2001-03-01 00:00:00  2001-04-01 00:00:00  \
# 0        398165.969974        396748.807840        394034.682061
# 1         22223.129407         25016.224513         22234.320323
# 2         17297.767938         20293.765145         17269.417648
# 3           267.612960           278.623623           298.010203
# 4          2825.408258          2801.145130          3849.574083
#
#    2001-05-01 00:00:00  2001-06-01 00:00:00  2001-07-01 00:00:00  ...  \
# ...

# %%
pd.wide_to_long(test, stubnames="200012", i=["cve_institucion","cve_concepto"], j="date")
# Out:
# Empty DataFrame
# ...

# %%
data=pd.read_csv("data/data_filtered.csv")

# %%
conditions=[
            data["cve_institucion"]==102,
            data["cve_institucion"]==172,
            data["cve_institucion"]==112,
            data["cve_institucion"]==40021,
            data["cve_institucion"]==136,
            data["cve_institucion"]==114,
            data["cve_institucion"]==144,

]
values=["Citibanamex","Banorte","BBVA Bancomer","HSBC","Inbursa","Santander","Scotiabank"]
data["Nombre"]=np.select(conditions,values)

# %%
data["Nombre"].unique()
# Out:
# array(['0', 'HSBC', 'Citibanamex', 'BBVA Bancomer', 'Santander',
#        'Inbursa', 'Scotiabank', 'Banorte'], dtype=object)

# %%
test=data.head()

# %%
data=data[data["Nombre"]!="0"]

# %%
data["Nombre"].unique()
# Out:
# array(['HSBC', 'Citibanamex', 'BBVA Bancomer', 'Santander', 'Inbursa',
#        'Scotiabank', 'Banorte'], dtype=object)

# %%
data.to_csv("jorgeQ.csv")
